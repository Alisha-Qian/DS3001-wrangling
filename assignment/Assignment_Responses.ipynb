# %% [markdown]
# # Assignment: Data Wrangling
# ## `! git clone https://github.com/DS3001/wrangling`
# ## Do Q2, and one of Q1 or Q3.

# %% [markdown]
# **Q1.** Open the "tidy_data.pdf" document in the repo, which is a paper called Tidy Data by Hadley Wickham.
#
#   1. Read the abstract. What is this paper about?
#   2. Read the introduction. What is the "tidy data standard" intended to accomplish?
#   3. Read the intro to section 2. What does this sentence mean: "Like families, tidy datasets are all alike but every messy dataset is messy in its own way." What does this sentence mean: "For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."
#   4. Read Section 2.2. How does Wickham define values, variables, and observations?
#   5. How is "Tidy Data" defined in section 2.3?
#   6. Read the intro to Section 3 and Section 3.1. What are the 5 most common problems with messy datasets? Why are the data in Table 4 messy? What is "melting" a dataset?
#   7. Why, specifically, is table 11 messy but table 12 tidy and "molten"?
#   8. Read Section 6. What is the "chicken-and-egg" problem with focusing on tidy data? What does Wickham hope happens in the future with further work on the subject of data wrangling?

# %% [markdown]
# 1. The paper is about tidy data and how to prepare it. That is, how to structure, clean, and organize data in a way so that it can be efficiently used/plugged into other tools.
# 2. It is used to facilitate exploration of data and it's analysis and simplify development of data analysis tools.
# 3. The first sentence means that all tidy sets are organized the same way but messy datasets aren't and can a variety of other issues as well/ways they differ from a tidy set. The second sentence means that given a table we can understand what are observations and what are variables, but when we organize the data into a table from a real life scenario/raw data it is not clear cut how the table should be made and what counts as it's own variable.
# 4. " Every value belongs to a variable and an
# observation. A variable contains all values that measure the same underlying attribute (like
# height, temperature, duration) across units. An observation contains all values measured on
# the same unit (like a person, or a day, or a race) across attributes."
# 5. Tidy data is a standard way of mapping the meaning of a dataset to its structure. Each variable is a column, rows are observations, table is an observational unit type.
# 6. • Column headers are values, not variable names.
# • Multiple variables are stored in one column.
# • Variables are stored in both rows and columns.
# • Multiple types of observational units are stored in the same table.
# • A single observational unit is stored in multiple tables.
# the column headers for table 4 are values, not names.
# Melting a dataset is turning the columns into rows. A new column contains the column headings while another column contains the frequency for this specific combination of observations.
# 7. table 11 is messy because each day of the month is its own variable but in 12 it's combined so each possible day is its own row. It is further tidied by making tmax and tmin variables of the same observation rather than their own seperate observations.
# 8. The problem is tidy tools are built on the structure of tidy data so they are linked and improvements can't just be made to one thing without the other. Ultimately he hopes others will develop better data storage strategies and tools.

# %% [markdown]
# **Q2.** This question provides some practice cleaning variables which have common problems.
# 1. Numeric variable: For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?)
# 2. Categorical variable: For the `./data/sharks.csv` data covered in the lecture, clean the "Type" variable as well as you can, and explain the choices you make.
# 3. Dummy variable: For the pretrial data covered in the lecture, clean the `WhetherDefendantWasReleasedPretrial` variable as well as you can, and, in particular, replace missing values with `np.nan`.
# 4. Missing values, not at random: For the pretrial data covered in the lecture, clean the `ImposedSentenceAllChargeInContactEvent` variable as well as you can, and explain the choices you make. (Hint: Look at the `SentenceTypeAllChargesAtConvictionInContactEvent` variable.)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('airbnb_hw.csv', low_memory=False)
price = df['Price']
price = price.str.replace(',','')
price = pd.to_numeric(price,errors='coerce')
#remove commas and makes them all numbers

# %%
df = pd.read_csv('sharks.csv', low_memory=False)
type = df['Type']
type = type.replace(['Sea Disaster', 'Boat','Boating','Boatomg'],'Watercraft')
type = type.replace(['Invalid', 'Questionable','Unconfirmed','Unverified','Under investigation'],np.nan)
df['Type'] = type
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].replace(['UNKNOWN', 'F','M','2017'],np.nan)
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].replace('y','Y')
#grouping similar categories together like all water vehicles, replacing investigation statuses with nan
# replacing other values of fatal with nan and making sure all y's are the same

# %%
df = pd.read_csv('VirginiaPretrialData2017.csv', low_memory=False)
df['WhetherDefendantWasReleasedPretrial'] =df['WhetherDefendantWasReleasedPretrial'].replace(9,np.nan)

# %%
length = df['ImposedSentenceAllChargeInContactEvent']
types = df['SentenceTypeAllChargesAtConvictionInContactEvent']
length = pd.to_numeric(length,errors='coerce')
length = length.mask( type == 4, 0)
length = length.mask( type == 9, np.nan)
df['ImposedSentenceAllChargeInContactEvent'] = length
#replace length with 0 for cases where charge was dismissed (type 4)
#replace length with nan when data is missing (type 9)

# %% [markdown]
# **Q3.** Many important datasets contain a race variable, typically limited to a handful of values often including Black, White, Asian, Latino, and Indigenous. This question looks at data gathering efforts on this variable by the U.S. Federal government.
#
# 1. How did the most recent US Census gather data on race?
# 2. Why do we gather these data? What role do these kinds of data play in politics and society? Why does data quality matter?
# 3. Please provide a constructive criticism of how the Census was conducted: What was done well? What do you think was missing? How should future large scale surveys be adjusted to best reflect the diversity of the population? Could some of the Census' good practices be adopted more widely to gather richer and more useful data?
# 4. How did the Census gather data on sex and gender? Please provide a similar constructive criticism of their practices.
# 5. When it comes to cleaning data, what concerns do you have about protected characteristics like sex, gender, sexual identity, or race? What challenges can you imagine arising when there are missing values? What good or bad practices might people adopt, and why?
# 6. Suppose someone invented an algorithm to impute values for protected characteristics like race, gender, sex, or sexuality. What kinds of concerns would you have?

# %% [markdown]
# 1. race is checkboxes with fill in the blank for more origins, Hispanic/Latino/Spanish origin is also asked  with fill ins for origins
# 2. We gather this data to better understand the population of certain areas which can lead to budget planning, fund allocation, development projects, and etc.. Data equality is important since the result of the data collection will have an impact on their lives as previously mentioned, so it's important everyone gets a fair chance and that the data is truly representative of the population.
# 3. I think it was done well. Something that's missing would maybe be a box for unsure if someone doesn't know their origins. The survey could be adjusted to include this and also a larger fill in the blank sections to specify more complicated racial backgrounds. I think the census' practices could be adopted more widely to gain useful data.
# 4. sex is check one box: male or female. This is pretty limiting as people can be nonbinary or trans or fluid or anything else. At least having more boxes for nonbinary, trans/cis, or 'other' would be more representative.
# 5. Some people may feel like gender/sexuality or even race are private matters and could be held against them in some way or are just uncomfortable sharing or unsure. When there are missing values the population starts to get misrepresented or overlooked and maybe even dropped from the dataset sometimes during cleaning. Some good practices would be having more options to be inclusive or fill in the blank but that would also create more confusion and lead to more data cleaning as the answers won't be standardized.
# 6. People would be misrepresented as something they are not. Not only is this a violation of their personal data but also would have societal impacts depending on what the data is used for. Also, it would be hard to train the algorithm since there would not be new 'real' data to train and test on, but only the ones it itself generated.
